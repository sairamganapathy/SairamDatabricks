# %%
# %sql
--create a sql script to get sum of customers per state from sales_customers table
SELECT state, COUNT(*) FROM samples.bakehouse.sales_customers GROUP BY state

# %%
def get_sales_customers_df():
    df = spark.table("samples.bakehouse.sales_customers")
    return df

dataframe = get_sales_customers_df()

def print_sales_customers_table(df1):
    display(df1)

# Call the function to display the dataframe
print_sales_customers_table(dataframe)
