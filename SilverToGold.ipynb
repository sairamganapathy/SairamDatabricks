# %%
# %sql
Create or replace table mytest.myschema.mytableSilver
as
select * from mytest.myschema.mytablenew

# %%
# %sql
select state, count(*) as countOfRecords
from mytest.myschema.mytableSilver
group by state
order by state
