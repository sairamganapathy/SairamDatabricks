# %%
df = spark.createDataFrame([(1, 'Product1', 'Category1', 10.0, 1, 5, '2022-01-01'),
                           (2, 'Product2', 'Category2', 20.0, 2, 3, '2022-01-02')], ['ProductID', 'ProductName', 'Category', 'Price', 'SaleID', 'Quantity', 'SaleDate'])
display(df)
